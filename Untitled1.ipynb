# %% [markdown]
# ### Perfil
#
# O formulário teve 57 respostas, 86% dos respondentes são negros

# %% [markdown]
# ![newplot%281%29.png](attachment:newplot%281%29.png)

# %% [markdown]
# ![newplot.png](attachment:newplot.png)
