# %% [markdown]
# # Análise de dados - Pesquisa Tombação, eixo saúde

# %% [markdown]
# Fonte de dados: formulário JotForm - base aqui.
#
# O questionário recebeu 57 respostas e está análise irá focar no eixo de saúde, a análise foi bivariada por raça e gênero com tabelas e alguns gráficos conforme visto abaixo. Na base há dados nulos, isto é; sem resposta.

# %% [markdown]
# ### Você usa ou já usou PrEP (Profilaxia Pré Exposição)?

# %% [markdown]
# A maioria dos respondentes declarou não usar Prep. Mesmo se considerarmos as categorias positivas para o uso (se já usou, ou usa) temos apenas 10 respostas que declaram já ter usado. Conforme tabela abaixo:

# %% [markdown]
# ![pqprep.png](attachment:pqprep.png)

# %% [markdown]
# Quando observamos os dados por raça temos em todas as categorias  que negros são a maioria, e  entre eles, 57% não usa conforme tabela abaixo;

# %% [markdown]
# ![prep_raca-3.png](attachment:prep_raca-3.png)

# %% [markdown]
# Mulheres trans, homens cis gênero e travestis são a maioria que não usa PrEp.

# %% [markdown]
# ![newplot.png](attachment:newplot.png)

# %% [markdown]
# ### Sabe para que serve a PrEP (Profilaxia Pré Exposição)?

# %% [markdown]
# 58% sabe para  que serve a PrEP (Profilaxia Pré Exposição) e 3 pessoas não responderam.
#
#
# ![pqprep.png](attachment:pqprep.png)

# %% [markdown]
# 61% dos respondentes negros sabem pra que serve
#
# ![pqprep_raca.png](attachment:pqprep_raca.png)

# %% [markdown]
# 45% são mulheres trans ou travestis.

# %% [markdown]
# ![newplot%2826%29.png](attachment:newplot%2826%29.png)

# %% [markdown]
# ##### Faz uso de algum medicamento controlado?

# %% [markdown]
# A maioria não faz uso de medicamento controlado

# %% [markdown]
# ![geral_medcontr.png](attachment:geral_medcontr.png)

# %% [markdown]
# Quando observamos os dados por raça visualizamos uma homogenidade quanto aos respondentes declarados negros que são a maioria

# %% [markdown]
# ![newplot%281%29.png](attachment:newplot%281%29.png)

# %% [markdown]
# E mulheres trans ou cis genero são as que precisa mas não usa.

# %% [markdown]
# ![medcontr_gen.png](attachment:medcontr_gen.png)

# %% [markdown]
# ##### Você utiliza algum medicamento para controle da carga viral do HIV?

# %% [markdown]
# 82% não usa  medicamento para controle da carga viral do HIV.

# %% [markdown]
# ![count_medhiv.png](attachment:count_medhiv.png)

# %% [markdown]
# Dos que usa, todos são negros e a maioria mulheres trans, mas há 4% que é  homens cis ou travestis.

# %% [markdown]
# ![medhiv_raca.png](attachment:medhiv_raca.png)

# %% [markdown]
# ![newplot%282%29.png](attachment:newplot%282%29.png)

# %% [markdown]
# ### Você já utilizou pílula do dia seguinte?

# %% [markdown]
# 82% não respondeu a pergunta e apenas 3 já fez uso de pílula  do dia seguinte

# %% [markdown]
# ![count_pilseg.png](attachment:count_pilseg.png)

# %% [markdown]
# Entre as que responderam que já recorreu à pílula do dia seguinte todas são mulheres cis e entre elas há negras, indígenas e brancas.

# %% [markdown]
# ![newplot%286%29.png](attachment:newplot%286%29.png)

# %% [markdown]
# Entre as negras apenas 1 faz uso de pílula do dia seguinte, mas 84% não faz.

# %% [markdown]
# ![pilseg_raca-2.png](attachment:pilseg_raca-2.png)

# %% [markdown]
# ### Com que frequência no ano você vai ao médico para consultas regulares?

# %% [markdown]
# Há uma parcela muito pequena que nunca vai ao médico e  26% raramente vai.

# %% [markdown]
# ![count_freqmed%20-2.png](attachment:count_freqmed%20-2.png)

# %% [markdown]
# 32% dos negros raramente vai e a metade dos brancos vão de uma a duas vezes no ano.

# %% [markdown]
# ![newplot%285%29.png](attachment:newplot%285%29.png)

# %% [markdown]
# Entre os que nunca vão há mulheres cis, travestis e Não binário. 71% das mulheres trans vão médico com alguma frequência

# %% [markdown]
# ![freqmed_gen-2.png](attachment:freqmed_gen-2.png)

# %% [markdown]
# ### Vai ao dentista com frequência?

# %% [markdown]
# 51% Raramente vai ou nunca vai ao dentista.

# %% [markdown]
# ![count_freqdent-2.png](attachment:count_freqdent-2.png)

# %% [markdown]
# Todos os indígenas raramente vão ou nunca ao dentista. E metade dos brancos vai ao menos uma vez ao ano.

# %% [markdown]
# ![freqdent_raca.png](attachment:freqdent_raca.png)

# %% [markdown]
# Entre homem cis a maioria vai ao menos 1 vez ao ano, já mulheres trans e travestis tem que a maioria nao vai ao dentista ou raramente.

# %% [markdown]
# ![freqdent_gen-2.png](attachment:freqdent_gen-2.png)

# %% [markdown]
# ###  Você já fez exame para HIV?

# %% [markdown]
# 79% já fez exame, a maioria é mullheres trans e negros. Todos outros e não binários já fizeram.

# %% [markdown]
# ![count_exhiv.png](attachment:count_exhiv.png)

# %% [markdown]
# Entre os brancos, 33% não fez. Já apenas 12% dos negros que não fizeram

# %% [markdown]
# ![exhiv_raca.png](attachment:exhiv_raca.png)

# %% [markdown]
# E 37% das  mulher cis não fizeram.

# %% [markdown]
# ![newplot%287%29.png](attachment:newplot%287%29.png)

# %% [markdown]
# ### Qual foi o resultado do exame de HIV?

# %% [markdown]
# 12% deu positivo e 23% não respondeu.

# %% [markdown]
# ![count_reshiv.png](attachment:count_reshiv.png)

# %% [markdown]
# Apenas pessoas negras positivaram

# %% [markdown]
# ![reshiv_raca.png](attachment:reshiv_raca.png)

# %% [markdown]
# ![newplot%288%29.png](attachment:newplot%288%29.png)

# %% [markdown]
# ### Você já fez exame para Sífilis?
#
# 74% já realizou exame de siflis, a maioria mulheres trans e declarados negros.
# E entre os que não fizeram, mulheres cis são a maioria.

# %% [markdown]
# ![count_exsif.png](attachment:count_exsif.png)

# %% [markdown]
# 33% dos brancos não fizeram e apenas 16% dos negros não fizeram.

# %% [markdown]
# ![exsif_raca.png](attachment:exsif_raca.png)

# %% [markdown]
# 9% dos travestis preferiu não responder e todos os Não binários e outros fizeram o exame

# %% [markdown]
# ![newplot%289%29.png](attachment:newplot%289%29.png)

# %% [markdown]
# ### Qual foi o resultado do exame de Sífilis?
#
# 49% foi negativo o resultado do exame e dos 23% que deu positivo grande parte são negros e travestis.

# %% [markdown]
# ![count_ressif.png](attachment:count_ressif.png)

# %% [markdown]
# E entre os que não fizeram, mulheres cis são a maioria.17% dos brancos positivou para siflis, o que difere de negros que tem 24% positivado

# %% [markdown]
# ![ressif_raca.png](attachment:ressif_raca.png)

# %% [markdown]
# ![newplot%2810%29.png](attachment:newplot%2810%29.png)

# %% [markdown]
# ### Você já fez exame para Hepatite B ou C?
#
# 67% fez o exame, a maioria sendo ulheres trans e negros.

# %% [markdown]
# ![count_exhep.png](attachment:count_exhep.png)

# %% [markdown]
# E 26% dos negros não fizeram

# %% [markdown]
# ![exhep_raca.png](attachment:exhep_raca.png)

# %% [markdown]
# ![newplot%2811%29.png](attachment:newplot%2811%29.png)

# %% [markdown]
# ### Qual foi o resultado do exame do exame de Hepatite B ou C?
#
# 2% positivou,todos são negros e trans

# %% [markdown]
# ![count_reshep.png](attachment:count_reshep.png)

# %% [markdown]
# ![reshep_raca.png](attachment:reshep_raca.png)

# %% [markdown]
# ![newplot%2812%29.png](attachment:newplot%2812%29.png)

# %% [markdown]
# ### Você já fez exame para outras IST's?
#
# Metade dos respondentes fizeram exame de outras IST's; a maioria negra e trans.

# %% [markdown]
# ![count_exist-2.png](attachment:count_exist-2.png)

# %% [markdown]
# ![exist_gen.png](attachment:exist_gen.png)

# %% [markdown]
# 47% dos negros fizeram o exame, e 50% dos brancos também.

# %% [markdown]
# ![exist_raca.png](attachment:exist_raca.png)

# %% [markdown]
# ### Qual foi o resultado do exame de IST's?
#
# 54% não respondeu. E todos positivados são negros

# %% [markdown]
# ![count_resist.png](attachment:count_resist.png)

# %% [markdown]
# ![resist_raca.png](attachment:resist_raca.png)

# %% [markdown]
# ![newplot%2814%29.png](attachment:newplot%2814%29.png)

# %% [markdown]
# ### Você faz uso de hormônios?
#
# 42% não faz uso.

# %% [markdown]
# ![count_hormo.png](attachment:count_hormo.png)

# %% [markdown]
# E todos que já fizeram uso, mas no faz mais são negros

# %% [markdown]
# ![hormo_raca-2.png](attachment:hormo_raca-2.png)

# %% [markdown]
# ![newplot%2815%29.png](attachment:newplot%2815%29.png)

# %% [markdown]
# ### Para qual finalidade você utiliza os hormônios?
#
# 65% não respondeu e maioria são homens cis.

# %% [markdown]
# ![count_fimhormo-2.png](attachment:count_fimhormo-2.png)

# %% [markdown]
# 54% das Travestis usam para terapia hormonal (mudanças corporais).

# %% [markdown]
# ![fimhormo_gen-2.png](attachment:fimhormo_gen-2.png)

# %% [markdown]
# E todos que usam para aceleração metabólica (ganho muscular, uso dietário) são negros.

# %% [markdown]
# ![fimhormo_raca-2.png](attachment:fimhormo_raca-2.png)

# %% [markdown]
# ### Você foi ao médico antes de tomar?
#
# 65% não respondeu, mas cada 14% foi ao médico. Dos que foram ao médico 50% são travestis e 90% negros.

# %% [markdown]
# ![count_medprehorm.png](attachment:count_medprehorm.png)

# %% [markdown]
# Ao observar os dados de raça temos que 17% dos brancos foram ao médico, enquanto apenas 14% dos negros foram ao médico.

# %% [markdown]
# ![medprehorm_raca.png](attachment:medprehorm_raca.png)

# %% [markdown]
# Apenas 3 mulheres trans que responderam foram ao médico antes de tomar hormônio.

# %% [markdown]
# ![medprehorm_gen-2.png](attachment:medprehorm_gen-2.png)

# %% [markdown]
# ### Você possui silicone industrial?
#
# 16% possui silicone, 89% são negras e 67% são travestis .

# %% [markdown]
# ![count_silic.png](attachment:count_silic.png)

# %% [markdown]
# 17% das mulheres brancas tem silicone, apenas 16% das negras tem

# %% [markdown]
# ![silic_raca-2.png](attachment:silic_raca-2.png)

# %% [markdown]
# ![newplot%2816%29.png](attachment:newplot%2816%29.png)

# %% [markdown]
# ### Você fuma?
#
# 54% é fumante, dos quais 45% é mulher trans e 90% negros.

# %% [markdown]
# ![count_fumo-2.png](attachment:count_fumo-2.png)

# %% [markdown]
# Dos que fumam só às vezes, todos são negros e 50% travesti.

# %% [markdown]
# ![newplot%2817%29.png](attachment:newplot%2817%29.png)

# %% [markdown]
# 67% da mulheres trans fumam.

# %% [markdown]
# ![fumo_gen-2.png](attachment:fumo_gen-2.png)

# %% [markdown]
# ### Você frequenta o posto de saúde na sua comunidade?
#
# 32% não frequenta.

# %% [markdown]
# ![count_frequs.png](attachment:count_frequs.png)

# %% [markdown]
# Entre os negros, 33% não frequenta enquanto entre os brancos apenas 17% que não.

# %% [markdown]
# ![frequs_raca-2.png](attachment:frequs_raca-2.png)

# %% [markdown]
# E 45% das travestis também não.

# %% [markdown]
# ![frequs_gen-2.png](attachment:frequs_gen-2.png)

# %% [markdown]
# ### Você usa ou já usou alguma dessas substâncias?
#
# 35% usa maconha.

# %% [markdown]
# ![count_usotox-2.png](attachment:count_usotox-2.png)

# %% [markdown]
# Quanto a raça 4% dos negros usam crack com alguma substância e 17% dos brancos usam maconha , cocaína, crack, LSD e Outras

# %% [markdown]
# ![usotox_raca-2.png](attachment:usotox_raca-2.png)

# %% [markdown]
# 36% das travestis usam e 50% de mulheres cis tbm.

# %% [markdown]
# ![usotox_gen-2.png](attachment:usotox_gen-2.png)

# %% [markdown]
# ### Por quais motivos você não frequenta o posto de saúde na sua comunidade?
#
# 26% respondeu e deste há apenas uma negra e travesti que sofreu discriminação.

# %% [markdown]
# ![count_motnfrequs-2.png](attachment:count_motnfrequs-2.png)

# %% [markdown]
# 14% dos negros diz que o serviço é limitado e nenhum branco respondeu.

# %% [markdown]
# ![motnfrequs_raca-2.png](attachment:motnfrequs_raca-2.png)

# %% [markdown]
# ![newplot%2818%29.png](attachment:newplot%2818%29.png)

# %% [markdown]
# ### Você já teve ou tem assistência psicológica?
#
# Há 1 homem negro cis que relata ter assistência psicológica por obrigação.

# %% [markdown]
# ![count_assistpsi-2.png](attachment:count_assistpsi-2.png)

# %% [markdown]
# Os que frequentam por vontade própria tem em sua maioria travestis

# %% [markdown]
# ![assistpsi_gen-2.png](attachment:assistpsi_gen-2.png)

# %% [markdown]
# Quanto aos dados de raça temos que entre os brancos que respoderam 67% frquenta e por vontade própria terapia.

# %% [markdown]
# ![assistpsi_raca-2.png](attachment:assistpsi_raca-2.png)

# %% [markdown]
# ### O posto médico na sua comunidade oferece assistência psicológica?
#
# Boa parten não sabe se existe oferta.

# %% [markdown]
# ![count_servpsi.png](attachment:count_servpsi.png)

# %% [markdown]
# Apenas 27% dos negros sabem das ofertas de terapia.

# %% [markdown]
# ![servpsi_raca-2.png](attachment:servpsi_raca-2.png)

# %% [markdown]
# e 55% das travestis não sabem

# %% [markdown]
# ![servsoc_gen-2.png](attachment:servsoc_gen-2.png)

# %% [markdown]
# ### O posto médico na sua comunidade possui assistência social?
#
#
# 32% não sabe se há assistência social.

# %% [markdown]
# ![count_servsoc-2.png](attachment:count_servsoc-2.png)

# %% [markdown]
# 42% dos negros sabe que existe esse serviço no posto da comunidade, mas todos os indigenas não sabem.

# %% [markdown]
# ![servsoc_raca-2.png](attachment:servsoc_raca-2.png)

# %% [markdown]
# Há Travestis, mulheres trans e homens cis que não possuem esse serviço na comunidade.

# %% [markdown]
# ![servsoc_gen-2.png](attachment:servsoc_gen-2.png)

# %% [markdown]
# ### O posto médico na sua comunidade distribui medicamentos que você precisa?
#
# 30% relata que o posto distribui sim , mas que o serviço é ruim e destes 83% são homens cis.

# %% [markdown]
# ![count_medcserv.png](attachment:count_medcserv.png)

# %% [markdown]
# Entre os brancos 60% relata que o posto distribui sim , mas que o serviço é ruim.

# %% [markdown]
# E 33% que não sabe são travestis.

# %% [markdown]
# ![medcserv_raca.png](attachment:medcserv_raca.png)

# %% [markdown]
# ![medcserv_gen-2.png](attachment:medcserv_gen-2.png)

# %% [markdown]
# ### Você recebeu a vacina contra Covid-19?
#
# 94%  já foi imunizada. E há 1 travesti que falta tomar a segunda dose.

# %% [markdown]
# ![count_vaccovid-2.png](attachment:count_vaccovid-2.png)

# %% [markdown]
# 2.2% dos negros ainda não tomou mas quer vacinar e entre brancos, todos já estão imunizados.

# %% [markdown]
# ![vaccovid_raca.png](attachment:vaccovid_raca.png)

# %% [markdown]
# Todos que ainda não vacinou são travestis.

# %% [markdown]
# ![newplot%2819%29.png](attachment:newplot%2819%29.png)

# %% [markdown]
# ### Quais destas vacinas você recebeu durante a vida?
#
# 19% Não sabe ou não lembra quais vacina recebeu.
# Abaixo o top 5 de vacinas mais tomadas

# %% [markdown]
# ![count_vacvida.png](attachment:count_vacvida.png)

# %% [markdown]
# ![vacina.png](attachment:vacina.png)

# %% [markdown]
# Quanto a raça a maioria,17%, dos negros não sabem ou não lembram.

# %% [markdown]
# ![vacvida_raca-2.png](attachment:vacvida_raca-2.png)

# %% [markdown]
# E 33% das mulheres trans também ão sabem

# %% [markdown]
# ![vacvida_gen-2.png](attachment:vacvida_gen-2.png)

# %% [markdown]
# ###  Você possui plano de saúde?
#
# Apenas 8% possui plano.  Mulheres trans e negros são a maioria que não possui.

# %% [markdown]
# ![count_plansaude-2.png](attachment:count_plansaude-2.png)

# %% [markdown]
# Apenas 4% dos respondentes negros possui plano, enquanto entre brancos 40% possui.

# %% [markdown]
# ![plansaude_raca.png](attachment:plansaude_raca.png)

# %% [markdown]
# Apenas homens e mulheres cis que possui plano de sáude, seja da empresa que trabalha ou sendo dependente.

# %% [markdown]
# ![plansaude_gen-2.png](attachment:plansaude_gen-2.png)

# %% [markdown]
# ### Você já foi diagnosticada com algum distúrbio ou transtorno?
#
# 28% possui diagnóstico de algum distúrbio, seja com laudo médico ou não.

# %% [markdown]
# ![count_disttranst-2.png](attachment:count_disttranst-2.png)

# %% [markdown]
# Entre os brancos 60% não possui distúrbios ou transtornos, já entre os negros apenas 49% não possui.

# %% [markdown]
# ![newplot%2820%29.png](attachment:newplot%2820%29.png)

# %% [markdown]
# 70% dos homens cis relatou não possui nenhum transtorno.

# %% [markdown]
# ![disttranst_gen-2.png](attachment:disttranst_gen-2.png)

# %% [markdown]
# ### Você se alimenta regularmente?
#
# 60% faz mais que duas refeições diárias, mas há 2% que se alimenta dia sim, dia não.

# %% [markdown]
# ![count_alimen-2.png](attachment:count_alimen-2.png)

# %% [markdown]
# Quando olhamos para raça dos respondentes, observamos que entre os brancos eles sempre se alimenta.

# %% [markdown]
# ![alimen_raca-2.png](attachment:alimen_raca-2.png)

# %% [markdown]
# Enquanto os nregos, 4% tem dificuldade em se alimentar e 6% se alimenta uma vez ao dia.

# %% [markdown]
# ![newplot%2821%29.png](attachment:newplot%2821%29.png)

# %% [markdown]
# ### Você já teve o seu resultado de exame de HIV exposto de maneira desautorizada ou constrangedora?
#
# 12% já teve essa exposição uma ou várias vezes.

# %% [markdown]
# ![count_expohiv.png](attachment:count_expohiv.png)

# %% [markdown]
# Pessoas negras são as mais expostas.

# %% [markdown]
# ![expohiv_raca.png](attachment:expohiv_raca.png)

# %% [markdown]
# E mulheres trans tem um percentual de exposição mais que uma vez em relaçao a outros grupos.

# %% [markdown]
# ![newplot%2823%29.png](attachment:newplot%2823%29.png)

# %% [markdown]
# ### Você utiliza os serviços ofertados pela clínica da família da sua região?
#
# 55% utiliza, seja ocasionalmente ou regularmente.

# %% [markdown]
# ![count_servcsf%20.png](attachment:count_servcsf%20.png)

# %% [markdown]
# Travestis são a maioria quenão utiliza.

# %% [markdown]
# ![newplot%2824%29.png](attachment:newplot%2824%29.png)

# %% [markdown]
# Apenas 23% dos negros usa regularmente os serviços ofertados.

# %% [markdown]
# ![servcsf_raca.png](attachment:servcsf_raca.png)

# %% [markdown]
# ### Por que você não utiliza os serviços da clínica da família?
#
# Boaparte dos respondentes relatou que os serviços da clinica da família são ruins e 4% diz que já foi maltratada/desrespeitada.

# %% [markdown]
# ![count_naocsf%20-2.png](attachment:count_naocsf%20-2.png)

# %% [markdown]
# Todos que relatou ter vergonha de expor minha situação de saúde no bairro/comunidade são negros.

# %% [markdown]
# ![naocsf_raca-2.png](attachment:naocsf_raca-2.png)

# %% [markdown]
# 50% dos que não conseguiu se cadastrar são travestis

# %% [markdown]
# ![newplot%2825%29.png](attachment:newplot%2825%29.png)

# %% [markdown]
# ### Você já recebeu diagnóstico positivo para COVID?
#
# 77% não positivou para COVID.

# %% [markdown]
# ![count_posicovid.png](attachment:count_posicovid.png)

# %% [markdown]
# Travestis e negros são a maioria que teve diagnóstico positivo.

# %% [markdown]
# ![posicovid_raca-2.png](attachment:posicovid_raca-2.png)

# %% [markdown]
# ![posicovid_gen-2.png](attachment:posicovid_gen-2.png)

# %% [markdown]
# ### Como você melhor descreveria seu quadro de saúde quando teve COVID?
#
# 82% não respondeu e apenas 5% foi assintomático.

# %% [markdown]
# ![count_quadcovid-2.png](attachment:count_quadcovid-2.png)

# %% [markdown]
# Apenas travestis, mulheres e homens cis ficaram assintomáticos.

# %% [markdown]
# ![newplot%2813%29.png](attachment:newplot%2813%29.png)

# %% [markdown]
# ### Você recebeu indicação para tratamento precoce da COVID-19?
#
# 60% dos respondentes não recebeu indicação para tratamento da covid.

# %% [markdown]
# ![count_prcccovid%20-2.png](attachment:count_prcccovid%20-2.png)

# %% [markdown]
# 2 travestis fizeram o tratamento por conta própria.

# %% [markdown]
# ![prcccovid_gen-2.png](attachment:prcccovid_gen-2.png)

# %% [markdown]
# 26% dos declarados negros fizeram o tratamento por amigos ou familiares.

# %% [markdown]
# ![prcccovid_raca-2.png](attachment:prcccovid_raca-2.png)
